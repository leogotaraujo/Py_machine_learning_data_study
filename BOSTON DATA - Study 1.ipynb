# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import load_boston
boston = load_boston()
print(boston.DESCR)
boston_df = boston.data
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
boston_df
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
boston
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %% [markdown]
# target (price) as index, features as columns, boston_df as my data

# %%
df = pd.DataFrame(boston_df, boston['target'], columns=boston['feature_names'])

# %% [markdown]
# Target is the price in thousands of Dollars

# %% [markdown]
# Now we have created this data set/ data frame, now i'll work on it

# %%
df.head()
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 24.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 21.6  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 34.7  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 33.4  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 36.2  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#       PTRATIO       B  LSTAT
# 24.0     15.3  396.90   4.98
# 21.6     17.8  396.90   9.14
# 34.7     17.8  392.83   4.03
# 33.4     18.7  394.63   2.94
# 36.2     18.7  396.90   5.33

# %%
df.insert(0,'PRICE', boston['target'])

# %%
df.drop(columns='level_0', inplace=True)
df.drop(columns='index', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1304\201794363.py in <module>
# ----> 1 df.drop(columns='level_0', inplace=True)
#       2 df.drop(columns='index', inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 506 entries, 24.0 to 11.9
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PRICE    506 non-null    float64
#  1   CRIM     506 non-null    float64
#  2   ZN       506 non-null    float64
#  3   INDUS    506 non-null    float64
#  4   CHAS     506 non-null    float64
#  5   NOX      506 non-null    float64
#  6   RM       506 non-null    float64
#  7   AGE      506 non-null    float64
#  8   DIS      506 non-null    float64
#  9   RAD      506 non-null    float64
#  10  TAX      506 non-null    float64
#  11  PTRATIO  506 non-null    float64
#  12  B        506 non-null    float64
#  13  LSTAT    506 non-null    float64
# dtypes: float64(14)
# memory usage: 59.3 KB

# %%
df.describe()
# Out:
#             PRICE        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.532806    3.613524   11.363636   11.136779    0.069170    0.554695
# std      9.197104    8.601545   23.322453    6.860353    0.253994    0.115878
# min      5.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%     17.025000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%     21.200000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%     25.000000    3.677083   12.500000   18.100000    0.000000    0.624000
# max     50.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
df.columns
# Out:
# Index(['PRICE', 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS',
#        'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
sns.pairplot(df)
# Out:
# C:\Users\leona\anaconda3\lib\site-packages\seaborn\_core.py:1057: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1304\4185451203.py in <module>
# ----> 1 sns.pairplot(df)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
# ...

# %%
sns.displot(df['PRICE'], kde=True)

# %%
df.columns
# Out:
# Index(['PRICE', 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS',
#        'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
X = df[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS',
       'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']]
y = df['PRICE']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# 38.5406203659776

# %%
lm.coef_
# Out:
# array([-9.53454396e-02,  2.69228120e-02,  2.53518593e-02,  2.66351535e+00,
#        -1.88198809e+01,  3.83494243e+00, -6.13760740e-03, -1.47346614e+00,
#         3.10954621e-01, -1.31162829e-02, -1.01257698e+00,  9.94879638e-03,
#        -5.20367446e-01])

# %%
X.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
cdf = pd.DataFrame(lm.coef_, X.columns, columns=['Coeff'])

# %%
cdf
# Out:
#              Coeff
# CRIM     -0.095345
# ZN        0.026923
# INDUS     0.025352
# CHAS      2.663515
# NOX     -18.819881
# RM        3.834942
# AGE      -0.006138
# DIS      -1.473466
# RAD       0.310955
# TAX      -0.013116
# PTRATIO  -1.012577
# B         0.009949
# LSTAT    -0.520367

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([10.45405237, 26.82768525, 15.79635037, 29.50342013, 12.81882221,
#        19.89957217, 21.41797249, 28.4686797 , 18.39141087, 36.08851308,
#         1.4900192 , 40.13852339, 25.61874917, 16.76025825, 20.9282731 ,
#        26.11192049, 34.33361187, 22.60986206, 19.92873022, 20.00337134,
#        24.53830327, 12.46854521, 17.92843251, 16.39515951, 12.11428903,
#        21.81511607, 24.10182539, 23.77644157, 24.55217605, 30.09529749,
#        20.70979017, 20.7389643 , 23.9750368 , 40.9278893 , 21.64006244,
#        20.73251033, 22.56863549, 16.07002858, 20.05144457, 13.38582776,
#        34.73830142, 26.74773409, 30.9160849 , 32.34932394, 13.93780231,
#        31.74959298, 23.40563618,  3.15901423, 19.74319966, 27.50511747,
#        26.6729739 , 19.64061946, 22.66828666, 29.89350741, 17.91453225,
#        30.21859586, 28.9431667 , 28.85498229, 20.45361456, 28.94804297,
#        20.00144039, 24.38052187, 26.09955893, 20.69072535, 20.48586855,
# ...

# %%
y_test
# Out:
# 23.1    23.1
# 22.3    22.3
# 15.2    15.2
# 32.9    32.9
# 12.8    12.8
#         ...
# 24.5    24.5
# 18.9    18.9
# 25.1    25.1
# 19.8    19.8
# 21.1    21.1
# Name: PRICE, Length: 167, dtype: float64

# %%
plt.scatter(y_test, predictions, )

# %%
sns.displot((y_test-predictions), kde=True)

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test, predictions)
# Out:
# 3.0800094402087983

# %%
metrics.mean_squared_error(y_test, predictions)
# Out:
# 18.50301244536269

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions))
# Out:
# 4.301512808926958
